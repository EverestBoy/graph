# %% [markdown]
# # Scatter plot

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,6,7,8,9,4,5]
y = [2,3,3,5,8,6,7,5,5]

# %%
plt.scatter(x,y);

# %%
plt.plot(x,y)

# %% [markdown]
# Scatter plot is very important plot for visualization data as such
